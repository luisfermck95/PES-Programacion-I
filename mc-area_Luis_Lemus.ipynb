# %% [markdown]
# ### Programa de Estudios Superiores 2019-2020
# ### Programación I - proyecto final
# #### Elaborado por <span class="alert alert-info"> ***Luis Fernando Lemus Mackay*** </span><br>
# ***
# ***Instrucciones generales:*** resuelve el siguiente problema de acuerdo a la especificación dada.
# - El código debe ir comentado para explicar la lógica y debe ser totalmente funcional para ser considerado correcto. De lo contrario, la calificación podrá ser subjetiva.
# - Al final de la definición de la clase, obtenga una instancia y muestra que el objeto se comporta de acuerdo a las especificaciones deseadas, para poder calificarte más rápidamente.
# ***

# %% [markdown]
# # Lanzamiento de dardos

# %% [markdown]
# Un catedrático de matemáticas dibuja en el pizarrón las funciones $f(x)=1-x^2$ y $g(x)=1-x$ para $0 \leq x \leq 1$. Al terminar de dibujar, se da cuenta que uno de sus alumnos está completamente dormido, así que decide despertarlo y pedirle que calcule el área entre curvas. El alumno, que se aburre en la clase de matemáticas, pero no en la de estadística y programación, le dice que es capaz de estimar el área sin necesidad de lo que ha enseñado mientras dormía. El catedrático le pide que lo demuestre en un cuaderno de *Jupyter*, pero que, además de calcular el área, desea que el programa cuente con otros requisitos.

# %% [markdown]
# <div class="alert alert-info">
# <b>Instrucciones</b>: <br>
#
# A continuación se le presenta el formato de la respuesta del estudiante. Usted debe completar el código y probar cada uno de los métodos en las casillas indicadas.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Ojo</b>: <br>
#
#  La gráfica debe contar con un sombreado entre ambas curvas, así como una leyeda indicando cada una de las funciones. Se adjunta un ejemplo.
#
# </div>

# %% [markdown]
# <img src="attachment:mc.png" width="400">

# %% [markdown]
# <div class="alert alert-info">
# <b>Importe los paquetes que sean necesarios</b>: <br>
#
#
# </div>

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from sympy import integrate, init_printing
from sympy.abc import x
init_printing(use_latex="mathjax")

# %% [markdown]
# <div class="alert alert-info">
# <b>Escriba su código en la celda siguiente</b>: <br>
#
#
# </div>

# %%
class AreaMonteCarlo(object):
    # %% ------------------------------------------------------------------------------------------------------
    """ En esta sección debe definir correctamente el método constructor. """
    def __init__(self,superior,inferior,infizq,supder, dardos=None, n=None):
        self.superior = superior  # Función correspondiente al límite superior del área sombreada.
        self.inferior = inferior # Función correspondiente al límite superior del área sombreada.
        self.infizq = infizq # Coordenadas correspondientes a la esquina inferior izquierda del rectángulo.
        self.supder = supder# Coordenadas correspondientes a la esquina superior derecha del rectángulo.
        self.dardos = None # Al inicio corresponde a un NoneType
        self.n = None # Número de dardos lanzados. Al inicio es NoneType.
    
    #def superior(self):
        #superior=
    # %% ------------------------------------------------------------------------------------------------------
    """ En esta sección debe definir un método que permita generar una matriz 
    de n filas y 2 columnas, rellena completamente de números aleatorios 
    uniformemente distribuidos. Dicha matrix debe ser almacenada el atributo 'dardos'"""
    
    def get_n(self):
        return self.n
    
    def set_n(self, newn):
        self.n = newn
        
    def lanzarDardos(self,n):
        self.matrix = np.random.random(size=(self.n,2))
        return self.matrix
    
    # %% ------------------------------------------------------------------------------------------------------
    """ En esta sección debe definir un método que grafique algo similar al ejemplo. 
    El método debe poder graficar aún cuando el atributo "dardo" esté vacío.
    Debe graficar en un rectágulo que tenga las esquinas 'infizq' y 'supder'
    como límites. Se debe poder elegir guardar o no la gráfica de 
    alta calidad con nombre 'mc.png'. La cantidad de filas 'n' se debe
    guardar en el atributo con mismo nombre. """
    
    def graficar(self, guardar=False):
        pass
    
    # %% ------------------------------------------------------------------------------------------------------
    #""" En esta sección calcule el área por método Monte Carlo. Debe devolver 
    #un flotante con el área. """"
    
    def calcularArea(self):
        pass
    
    # %% ------------------------------------------------------------------------------------------------------
    """ En esta sección, escriba un método que devuelva un DataFrame con las
    siguientes columnas:
        - Coordenada en x del dardo
        - Coordenada en y del dardo
        - 1 si está dentro del área y 0 si no lo está. 
        
        Se debe poder elegir guardar un archivo mc.csv con los resultados."""
    def dardosResultados(self, guardar=False):
        pass

# %% [markdown]
# ***
# ## Área de pruebas personal
#
# Utilice el siguiente espacio para llevar a cabo **sus** pruebas.

# %%
matrix= np.random.random(size=(1000,2))#Se define una matriz de n filas con 1 columna que representa las coordenadas de x
matrix
# Out:
# array([[0.85254799, 0.71990118],
#        [0.25147944, 0.4883456 ],
#        [0.31159957, 0.42933973],
#        ...,
#        [0.47592921, 0.35306979],
#        [0.1134518 , 0.56796855],
#        [0.9501328 , 0.81800749]])

# %%
coor_x=matrix[:,0]
coor_x
# Out:
# array([0.85254799, 0.25147944, 0.31159957, 0.66793774, 0.61024595,
#        0.87341703, 0.5936792 , 0.35196788, 0.21538328, 0.78301418,
#        0.67818911, 0.34217882, 0.62088806, 0.83021257, 0.88988823,
#        0.25459625, 0.47071375, 0.14860002, 0.60344218, 0.95972157,
#        0.09022086, 0.89333786, 0.76806332, 0.06812892, 0.91026824,
#        0.25383725, 0.80026769, 0.10756333, 0.44135293, 0.71891618,
#        0.36287742, 0.3129836 , 0.43155168, 0.26797577, 0.58208099,
#        0.20218923, 0.62051306, 0.79599659, 0.16568313, 0.67625887,
#        0.92438412, 0.93010864, 0.04978608, 0.20362549, 0.45026013,
#        0.7594609 , 0.95695408, 0.83356319, 0.3739132 , 0.33552167,
#        0.32335413, 0.68806108, 0.64179625, 0.35576158, 0.7413473 ,
#        0.33650955, 0.38296207, 0.08881771, 0.71654108, 0.50334777,
#        0.25613323, 0.40793992, 0.84351177, 0.40395448, 0.41858999,
#        0.11951918, 0.56768783, 0.12508259, 0.67105634, 0.87655189,
#        0.63824124, 0.27108378, 0.08361344, 0.23087521, 0.09040657,
#        0.25737701, 0.80999077, 0.26870458, 0.73873255, 0.71190178,
#        0.08000419, 0.13878994, 0.63929127, 0.2494624 , 0.6515557 ,
#        0.76658667, 0.77044121, 0.15610481, 0.49740589, 0.31432296,
#        0.99521725, 0.34247851, 0.24080279, 0.88905167, 0.59295092,
#        0.86329523, 0.08269737, 0.82712747, 0.00319599, 0.02284485,
#        0.72956789, 0.06719142, 0.98625772, 0.67259648, 0.36691929,
#        0.52309949, 0.18273498, 0.94218628, 0.06346009, 0.66999513,
#        0.61753947, 0.50008439, 0.85834851, 0.95857347, 0.1035753 ,
#        0.21872771, 0.18467752, 0.21891925, 0.52713754, 0.53601868,
#        5.86049232e-01, 3.53069793e-01, 5.67968549e-01, 8.18007492e-01])

# %%
y_coor=pd.Series((matrix[::,1]))#Dichas coordenadas en un array se pasan a formato serie 
y_coor
# Out:
# 0      0.719901
# 1      0.488346
# 2      0.429340
# 3      0.388088
# 4      0.034077
#          ...
# 995    0.792387
# 996    0.586049
# 997    0.353070
# 998    0.567969
# 999    0.818007
# Length: 1000, dtype: float64

# %%
#def superior(x_coor): #Se define una función superior en la que se evalúa la serie x en la función 1-x**2 para obtner y 
    #return 1-(x_coor)**2

# %%
#y3=superior(x_coor)
#y3

# %%
#def inferior(x_coor): #Se define una función inferior en la que se evalúa la serie x en la función 1-x para obtener y2
    #return 1-(x_coor)

# %%
#y4=inferior(x_coor)
#y4

# %%
x_coordinates = x_coor
y_coordinates = y_coor
df = pd.DataFrame({ 'x': x_coordinates, 'y': y_coordinates})#Diccionario
df
# Out:
#             x         y
# 0    0.096284  0.719901
# 1    0.527884  0.488346
# 2    0.296592  0.429340
# 3    0.792483  0.388088
# 4    0.600701  0.034077
# ..        ...       ...
# 995  0.924953  0.792387
# 996  0.615964  0.586049
# 997  0.194739  0.353070
# 998  0.494932  0.567969
# 999  0.795057  0.818007
#
# [1000 rows x 2 columns]

# %%
x = np.linspace(0, 1)
y1 = 1-(x ** 2)
y2 = -x+1
# create a figure/canvas of desired size
plt.figure(figsize=(8, 6))

# plot values; with a color `blue`
plt.plot(x, y1, 'b')
plt.plot(x, y2, '#FF8000')
plt.scatter(df['x'],df['y'],s=None,c='red')


# give labels to the axes
plt.xlabel('x')
plt.ylabel('y')


# give a title to the plot
plt.title(r"Plot of $y=1-x^2$ and $y=1-x$")
plt.show()

# %%
y = df['y']
y
# Out:
# 0      0.719901
# 1      0.488346
# 2      0.429340
# 3      0.388088
# 4      0.034077
#          ...
# 995    0.792387
# 996    0.586049
# 997    0.353070
# 998    0.567969
# 999    0.818007
# Name: y, Length: 1000, dtype: float64

# %%
x = df['x']
x
# Out:
# 0      0.096284
# 1      0.527884
# 2      0.296592
# 3      0.792483
# 4      0.600701
#          ...
# 995    0.924953
# 996    0.615964
# 997    0.194739
# 998    0.494932
# 999    0.795057
# Name: x, Length: 1000, dtype: float64

# %%
dots_und=df[df.y < (1-x**2)]#Devuelve el data frame con las coordenas que se encuentran por debajo de la función 
#cuadrática
dots_und
# Out:
#             x         y
# 0    0.096284  0.719901
# 1    0.527884  0.488346
# 2    0.296592  0.429340
# 4    0.600701  0.034077
# 7    0.645879  0.434135
# ..        ...       ...
# 993  0.664409  0.244569
# 994  0.275596  0.425893
# 996  0.615964  0.586049
# 997  0.194739  0.353070
# 998  0.494932  0.567969
#
# [664 rows x 2 columns]

# %%
#Se verifica que sean los puntos efectivamente debajo de la función cuadrática

# %%
x = np.linspace(0, 1)
y1 = 1-(x ** 2)
y2 = -x+1
# create a figure/canvas of desired size
plt.figure(figsize=(8, 6))

# plot values; with a color `blue`
plt.plot(x, y1, 'b')
plt.plot(x, y2, '#FF8000')
plt.scatter(dots_und['x'],dots_und['y'],s=None,c='red')


# give labels to the axes
plt.xlabel('x')
plt.ylabel('y')


# give a title to the plot
plt.title(r"Plot of $y=1-x^2$ and $y=1-x$")
plt.show()

# %%
dots_abv=df[df.y > (1-x)]#Devuelve el data frame con las coordenas que se encuentran por encima de la función 
#lineal
dots_abv
# Out:
#             x         y
# 1    0.527884  0.488346
# 3    0.792483  0.388088
# 5    0.519999  0.835633
# 6    0.384831  0.885250
# 7    0.645879  0.434135
# ..        ...       ...
# 990  0.964953  0.310159
# 995  0.924953  0.792387
# 996  0.615964  0.586049
# 998  0.494932  0.567969
# 999  0.795057  0.818007
#
# [496 rows x 2 columns]

# %%
#Se verifica que sean los puntos efectivamente por encima de la función lineal

# %%
x = np.linspace(0, 1)
y1 = 1-(x ** 2)
y2 = -x+1
# create a figure/canvas of desired size
plt.figure(figsize=(8, 6))

# plot values; with a color `blue`
plt.plot(x, y1, 'b')
plt.plot(x, y2, '#FF8000')
plt.scatter(dots_abv['x'],dots_abv['y'],s=None,c='red')


# give labels to the axes
plt.xlabel('x')
plt.ylabel('y')


# give a title to the plot
plt.title(r"Plot of $y=1-x^2$ and $y=1-x$")
plt.show()

# %%
(1-x).shape
# Out:
# (1000,)

# %%
df.y.values.shape
# Out:
# (1000,)

# %%
dots_btw=df[(df.y.values > (1-x))& (df.y.values<(1-x**2))]
dots_btw
# Out:
#             x         y
# 1    0.527884  0.488346
# 7    0.645879  0.434135
# 10   0.515979  0.545006
# 14   0.386004  0.740442
# 15   0.266164  0.801379
# ..        ...       ...
# 966  0.158884  0.953155
# 975  0.221853  0.854273
# 979  0.491079  0.582035
# 996  0.615964  0.586049
# 998  0.494932  0.567969
#
# [160 rows x 2 columns]

# %%
#Se verifica que se obtengan los puntos de en medio

# %%
x = np.linspace(0, 1)
y1 = 1-(x ** 2)
y2 = -x+1
# create a figure/canvas of desired size
plt.figure(figsize=(8, 6))

# plot values; with a color `blue`
plt.plot(x, y1, 'b')
plt.plot(x, y2, '#FF8000')
plt.scatter(dots_btw['x'],dots_btw['y'],s=None,c='red')


# give labels to the axes
plt.xlabel('x')
plt.ylabel('y')


# give a title to the plot
plt.title(r"Plot of $y=1-x^2$ and $y=1-x$")
plt.show()

# %%
y_btw = dots_btw['y']
y_btw
# Out:
# 1      0.488346
# 7      0.434135
# 10     0.545006
# 14     0.740442
# 15     0.801379
#          ...
# 966    0.953155
# 975    0.854273
# 979    0.582035
# 996    0.586049
# 998    0.567969
# Name: y, Length: 160, dtype: float64

# %%
y_btw.count()
# Out:
# 160

# %%
y.count()
# Out:
# 1000

# %%
Area=y_btw.count()/y.count()
Area
# Out:
# 0.16

# %% [markdown]
# ***
# ## Área de pruebas para calificación
#
# Utilice el siguiente espacio para mostrarnos su implementación terminada.

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "lanzarDardos"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "graficar"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "calcularArea"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Pruebe el método "dardosResultados"</b>: <br>
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Muestre cada uno de los atribujos del objeto utilizado en el ejemplo</b>: <br>
# </div>
